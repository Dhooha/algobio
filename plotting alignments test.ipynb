# %%
#install library
install.packages("RColorBrewer", repos ="http://cran.us.r-project.org")
install.packages("circlize", repos ="http://cran.us.r-project.org")
# Out:
# Installing package into 'C:/Users/abidd/Documents/R/win-library/3.3'
# (as 'lib' is unspecified)
# package 'RColorBrewer' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\abidd\AppData\Local\Temp\RtmpKcsqC8\downloaded_packages

# %%
n <- c("#7FC97F", "#BEAED4", "#FDC086", "#FFFF99", "#386CB0", "#F0027F", "#BF5B17")

# %%
plot.new()
legend('bottom','groups',c("#7FC97F", "#BEAED4", "#FDC086", "#FFFF99", "#386CB0", "#F0027F", "#BF5B17",
 "#666666", "#1B9E77", "#D95F02", "#7570B3", "#E7298A", "#66A61E", "#E6AB02",
 "#A6761D", "#666666", "#A6CEE3", "#1F78B4", "#B2DF8A", "#33A02C", "#FB9A99",
 "#E31A1C", "#FDBF6F", "#FF7F00", "#CAB2D6", "#6A3D9A", "#FFFF99", "#B15928",
 "#FBB4AE", "#B3CDE3", "#CCEBC5", "#DECBE4", "#FED9A6", "#FFFFCC", "#E5D8BD",
 "#FDDAEC", "#F2F2F2", "#B3E2CD", "#FDCDAC", "#CBD5E8", "#F4CAE4", "#E6F5C9",
 "#FFF2AE", "#F1E2CC", "#CCCCCC", "#E41A1C", "#377EB8", "#4DAF4A", "#984EA3",
 "#FF7F00", "#FFFF33", "#A65628", "#F781BF", "#999999", "#66C2A5", "#FC8D62",
 "#8DA0CB", "#E78AC3", "#A6D854", "#FFD92F", "#E5C494", "#B3B3B3", "#8DD3C7",
 "#FFFFB3", "#BEBADA", "#FB8072", "#80B1D3", "#FDB462", "#B3DE69", "#FCCDE5",
 "#D9D9D9", "#BC80BD", "#CCEBC5", "#FFED6F"), lty = c(1), lwd=5,
       
       
       col=c("#7FC97F", "#BEAED4", "#FDC086", "#FFFF99", "#386CB0", "#F0027F", "#BF5B17",
 "#666666", "#1B9E77", "#D95F02", "#7570B3", "#E7298A", "#66A61E", "#E6AB02",
 "#A6761D", "#666666", "#A6CEE3", "#1F78B4", "#B2DF8A", "#33A02C", "#FB9A99",
 "#E31A1C", "#FDBF6F", "#FF7F00", "#CAB2D6", "#6A3D9A", "#FFFF99", "#B15928",
 "#FBB4AE", "#B3CDE3", "#CCEBC5", "#DECBE4", "#FED9A6", "#FFFFCC", "#E5D8BD",
 "#FDDAEC", "#F2F2F2", "#B3E2CD", "#FDCDAC", "#CBD5E8", "#F4CAE4", "#E6F5C9",
 "#FFF2AE", "#F1E2CC", "#CCCCCC", "#E41A1C", "#377EB8", "#4DAF4A", "#984EA3",
 "#FF7F00", "#FFFF33", "#A65628", "#F781BF", "#999999", "#66C2A5", "#FC8D62",
 "#8DA0CB", "#E78AC3", "#A6D854", "#FFD92F", "#E5C494", "#B3B3B3", "#8DD3C7",
 "#FFFFB3", "#BEBADA", "#FB8072", "#80B1D3", "#FDB462", "#B3DE69", "#FCCDE5",
 "#D9D9D9", "#BC80BD", "#CCEBC5", "#FFED6F"),
       ncol=2,bty ="n")
# Out:
# plot without title

# %%
plot.new()
legend('bottom','groups',c("#7FC97F", "#BEAED4", "#FDC086", "#FFFF99", "#386CB0", "#F0027F", "#BF5B17",
 "#666666", "#1B9E77", "#D95F02", "#7570B3", "#E7298A", "#66A61E", "#E6AB02", "#FB9A99"), lty = c(1), lwd=5,
       
       
       col=c("#7FC97F", "#BEAED4", "#FDC086", "#FFFF99", "#386CB0", "#F0027F", "#BF5B17",
 "#666666", "#1B9E77", "#D95F02", "#7570B3", "#E7298A", "#66A61E", "#E6AB02", "#FB9A99"),
       ncol=2,bty ="n")
# Out:
# plot without title

# %%
library("circlize")

#assign different colors to every chromosome
lcc <- list(chr1 = "#7FC97F", chr2 = "#BEAED4", chr3 = "#FDC086", chr4 = "#FFFF99", chr5 = "#386CB0", chr6 = "#CCCCCC", 
            chr7 = "#BF2000", chr8 = "#666666", chr9 = "#1B9E77", chr10 = "#D95F02", chr11 = "#7570B3", chr12 = "#E7298A",
            chr13 = "#66A61E", chr14 = "#E6AB02", chr15 = "#A6761D", chr16 = "#666666", chr17 = "#A6CEE3", chr18 = "#1F78B4",
            chr19 = "#FC8000", chr20 = "#000099", chr21 = "black"  , chr22 = "#BC80BD", chrX = "#FB9A99", chrY = "#E31A1C", 
            chr8_KI270926v1_alt ="#F781BF", chr9_KI270823v1_alt="#FB8072", chr14_KI270846v1_alt="green", chr17_KI270857v1_alt="#B3DE69")

#list of all the aav serotype to loop  over them
l <- c("AAV1", "AAV2", "AAV3", "AAV4", "AAV5", "AAV7", "AAV8")

#define the file to plot
#pathfile = "C:/Users/abidd/Dropbox/algobio/res-tblastn/tblastn-o6-100-p2.csv" #BLOSUM62
#BLOSUM = "-B62"

pathfile = "C:/Users/abidd/Dropbox/algobio/res-tblastn/tblastn-o6-100-B45-p.csv" #BLOSUM45
BLOSUM = "-B45"

#read tblastn-o6-100-p.csv to retrieve the start and end of matches
dataall <- read.csv(pathfile, header=TRUE)
colnames(dataall) <- c("rc", "aav", "qseqid","sseqid","pident","length","mismatch","gapopen","qstart","qend","sstart","send","evalue","bitscore")

#loop over all the virus
for (av in l){
    print(av)

    #----------------------------------------------------
    #define data frame for every serotype
    #with the corresponding length of Rep, Cap and others
    if (av[[1]] == "AAV1" ){
        n = c("nonstructural protein", "capsid protein")
        s = c(1, 1)
        e = c(623, 736)
    } else if(av[[1]] == "AAV2"){
        n = c("Rep 68 protein", "Rep 78 protein", 
              "Rep 40 protein", "Rep 52 protein", 
              "major coat protein VP1", "major coat protein VP2",
              "assembly activating protein AAP", "major coat protein VP3", "X protein")
        s = c(1, 1, 1, 1, 1, 1, 1, 1, 1)
        e = c(536, 621, 312, 397, 735, 598, 204, 533, 155)
    }else if (av[[1]] == "AAV3"){
        n = c("nonstructural protein", "capsid protein")
        s = c(1, 1)
        e = c(624, 736)
    }else if (av[[1]] == "AAV4"){
        n = c("rep", "capsid")
        s = c(1, 1)
        e = c(623, 734)
    }else if (av[[1]] == "AAV5"){
        n = c("DNA binding trs helicase", "capsid protein")
        s = c(1, 1)
        e = c(610, 724)
    }else if (av[[1]] == "AAV7"){
        n = c("nonstructural protein", "capsid protein")
        s = c(1, 1)
        e = c(623, 737)
    }else if (av[[1]] == "AAV8"){
        n = c("nonstructural protein", "capsid protein")
        s = c(1, 1)
        e = c(625, 738)
    }
    
    #end definition frame for every serotype
    #----------------------------------------------------
        
    #to save the plot in a png file
    png(paste(av[[1]], BLOSUM, ".png", sep=""), width=7, height=7, units="in", res=700)
    par(mar=c(4,4,4,4)) #set up the margins

    #set up data frame for the corresponding serotype
    df = data.frame(
    name = n,
    start = s,
    end = e)
    circos.genomicInitialize(df)

    #pull the subset of the corresponding serotype
    data <- subset(dataall, aav == av[[1]])
    
    #retrieve virus, chr, start and end positions
    aav = data$aav #using $ sign is a factor list, while using data[1] create a data frame
    sseqid = data$sseqid 
    qstart =data$qstart
    qend = data$qend
    rc = data$rc

    #plot Rep & Cap in different colors
    circos.genomicTrackPlotRegion(ylim = c(0, 1),
    bg.col = c("#FF000040", "#00FF0040", "#0000FF40", "#FFF55590", "#666666", "#377EB8", "#FF7F00", "#BEAED4", "#B2DF8A"),
    bg.border = NA, track.height = 0.05)

    #number of rows/alignments by serotype 
    n = max(sapply(data, length))  
    print(n)
    #plot the alignments
    circos.genomicTrackPlotRegion(ylim = c(0.5, n + 0.5), #position in the plot
        panel.fun = function(region, value, ...) {
        for (i in seq_along(sseqid)){ #loop over the corresponsding aav alignments/matches
            if (trimws(get.cell.meta.data("sector.index")) == trimws(rc[i])){ #if this alignment correspond to this data frame
                circos.lines(c(qstart[i], qend[i]), #plot the alignment into a line
                    lwd = 3, #define thickness
                    c(n-i, n-i), #position in the plot
                    col = lcc[toString(sseqid[i][[1]], ...)][[1]]) #define color- color depends on chromosome
                    #put sseqid into toString to not get errounous colors
                    #col = "orange")
            }
        }
}, bg.border = NA, track.height = 0.3)
    

    
#to plot the corresponding aav label
x = seq(-10, 10, length.out=100)/40
text(x[ceiling(length(x)/2)], -0.08, paste(av[[1]], BLOSUM, sep=""), adj = c(0.5, 1), cex = 1.2)
#legend('center','groups',av[[1]], ncol =1, bty = "n")

    
#uncomments these line to plot the legend
#plot.new()
#legend('bottom',c("chr1" , "chr2", "chr3", "chr4", "chr5" , "chr6" , 
#            "chr7" , "chr8" , "chr9" , "chr10" , "chr11", "chr12" ,
#            "chr13" , "chr14" , "chr15", "chr16" , "chr17" , "chr18" ,
#            "chr19" , "chr20", "chr21"   , "chr22", "chrX" , "chrY" , 
#            "chr8_KI270926v1_alt", "chr9_KI270823v1_alt", "chr14_KI270846v1_alt", "chr17_KI270857v1_alt"), lty = c(1), lwd=5,
       
       
#       col=c("#7FC97F", "#BEAED4", "#FDC086", "#FFFF99", "#386CB0", "#CCCCCC", 
#            "#BF2000", "#666666", "#1B9E77", "#D95F02", "#7570B3", "#E7298A",
#            "#66A61E", "#E6AB02", "#A6761D", "#666666", "#A6CEE3", "#1F78B4",
#            "#FC8000", "#000099", "black"  , "#BC80BD", "#FB9A99", "#E31A1C", 
#            "#F781BF", "#FB8072", "green", "#B3DE69"),
#       ncol=2)

circos.clear()

# to save the plot as image
dev.off()
    
    
}
# Out:
# [1] "AAV1"
# [1] 20
# [1] "AAV2"
# [1] 226
# [1] "AAV3"
# [1] 21
# [1] "AAV4"
# [1] 23
# [1] "AAV5"
# [1] 16
# [1] "AAV7"
# [1] 24
# [1] "AAV8"
# [1] 20

# %%
library(circlize) 

# dend: as dendrogram object, usually returned by hclust and as.dendrogram
# maxy: maximum height of the tree
circos.dendrogram = function(dend, maxy) {
  labels = as.character(labels(dend))
    x = seq_along(labels) - 0.5
    names(x) = labels

    is.leaf = function(object) (is.logical(L <- attr(object, "leaf"))) && L
    
    # recursive function to draw the tree
    draw.d = function(dend, maxy) {
        leaf = attr(dend, "leaf")
        d1 = dend[[1]]
        d2 = dend[[2]]
        height = attr(dend, 'height')
        midpoint = attr(dend, 'midpoint')

        if(is.leaf(d1)) {
            x1 = x[as.character(attr(d1, "label"))]
        } else {
            x1 = attr(d1, "midpoint") + x[as.character(labels(d1))[1]]
        }
        y1 = attr(d1, "height")

        if(is.leaf(d2)) {
            x2 = x[as.character(attr(d2, "label"))]
        } else {
            x2 = attr(d2, "midpoint") + x[as.character(labels(d2))[1]]
        }
        y2 = attr(d2, "height")

        circos.lines(c(x1, x1), maxy - c(y1, height), straight = TRUE)
        circos.lines(c(x1, x2), maxy - c(height, height))
        circos.lines(c(x2, x2), maxy - c(y2, height), straight = TRUE)

        if(!is.leaf(d1)) {
            draw.d(d1, maxy)
        }
        if(!is.leaf(d2)) {
            draw.d(d2, maxy)
        }
    }
    
    draw.d(dend, maxy)
}


mat = matrix(rnorm(100*10), nrow = 10, ncol = 100)
factors = rep(letters[1:2], 50)
par(mar = c(1, 1, 1, 1))
circos.par(cell.padding = c(0, 0, 0, 0), gap.degree = 5)
circos.initialize(factors, xlim = c(0, 50))
maxy = 0

f = colorRamp2(breaks = c(-1, 0, 1), colors = c("green", "black", "red"))

circos.trackPlotRegion(ylim = c(0, 10), bg.border = NA, panel.fun = function(x, y) {
  sector.index = get.cell.meta.data("sector.index")
    m = mat[, factors == sector.index]
    
    dend.col = as.dendrogram(hclust(dist(t(m))))

    maxy = ifelse(maxy > attr(dend.col, "height"), maxy, attr(dend.col, "height"))
    assign("maxy", maxy, envir = .GlobalEnv)

    m2 = m[, labels(dend.col)]
    nr = nrow(m2)
    nc = ncol(m2)
    for(i in 1:nr) {
        for(j in 1:nc) {
            circos.rect(j-1, nr-i, j, nr-i+1, border = f(m2[i, j]), col = f(m2[i, j]))
        }
    }
    
})
circos.trackPlotRegion(ylim = c(0, maxy), bg.border = NA, track.height = 0.3, panel.fun = function(x, y) {
    sector.index = get.cell.meta.data("sector.index")
    m = mat[, factors == sector.index]
    
    dend.col = as.dendrogram(hclust(dist(t(m))))

    circos.dendrogram(dend.col, maxy)
    
})

circos.clear()
    
x = seq(-10, 10, length.out=100)/40


text(x[1], -0.08, "-2", adj = c(0.5, 1), cex = 1.2)
text(x[ceiling(length(x)/2)], -0.08, "0", adj = c(0.5, 1), cex = 1.2)
text(x[length(x)], -0.08, "2", adj = c(0.5, 1), cex = 1.2)
# Out:
# plot without title

# %%
x[1]
# Out:
# [1] -0.25

# %%
load(paste0(system.file(package = "circlize"), "/extdata/tp_family.RData"))
names(tp_family)
## [1] "TP73" "TP63" "TP53"
names(tp_family[["TP53"]])
## [1] "ENST00000413465.2" "ENST00000359597.4" "ENST00000504937.1"
## [4] "ENST00000269305.4" "ENST00000510385.1" "ENST00000504290.1"
## [7] "ENST00000455263.2" "ENST00000420246.2" "ENST00000445888.2"
## [10] "ENST00000576024.1" "ENST00000509690.1" "ENST00000514944.1"
## [13] "ENST00000574684.1" "ENST00000505014.1" "ENST00000508793.1"
## [16] "ENST00000604348.1" "ENST00000503591.1"
head(tp_family[["TP53"]][[1]])
## start end
## exon_7 7565097 7565332
## exon_6 7577499 7577608
## exon_5 7578177 7578289
## exon_4 7578371 7578554
## exon_3 7579312 7579590
## exon_2 7579700 7579721
df = data.frame(gene = names(tp_family),
start = sapply(tp_family, function(x) min(unlist(x))),
end = sapply(tp_family, function(x) max(unlist(x))))
df
    
circos.genomicInitialize(df)

#to plot the chr in different colors
circos.genomicTrackPlotRegion(ylim = c(0, 1),
bg.col = c("#FF000040", "#00FF0040", "#0000FF40"),
bg.border = NA, track.height = 0.05)
    
n = max(sapply(tp_family, length))
print(n)
circos.genomicTrackPlotRegion(ylim = c(0.5, n + 0.5),
panel.fun = function(region, value, ...) {
gn = get.cell.meta.data("sector.index")
print(gn)
tr = tp_family[[gn]] # all transcripts for this gene

for(i in seq_along(tr)) {

# for each transcript
current_tr_start = min(tr[[i]]$start)
current_tr_end = max(tr[[i]]$end)
circos.lines(c(current_tr_start, current_tr_end),
c(n - i, n - i), col = "#CCCCCC")

print (tr[i])
circos.genomicRect(tr[[i]], ytop = n - i + 0.4,
ybottom = n - i - 0.4, col = "orange", border = NA)

}
}, bg.border = NA, track.height = 0.3)

circos.clear()
# Out:
# [1] "TP73" "TP63" "TP53"
#  [1] "ENST00000413465.2" "ENST00000359597.4" "ENST00000504937.1"
#  [4] "ENST00000269305.4" "ENST00000510385.1" "ENST00000504290.1"
#  [7] "ENST00000455263.2" "ENST00000420246.2" "ENST00000445888.2"
# [10] "ENST00000576024.1" "ENST00000509690.1" "ENST00000514944.1"
# [13] "ENST00000574684.1" "ENST00000505014.1" "ENST00000508793.1"
# [16] "ENST00000604348.1" "ENST00000503591.1"
#          start     end
# exon_7 7565097 7565332
# exon_6 7577499 7577608
# exon_5 7578177 7578289
# exon_4 7578371 7578554
# exon_3 7579312 7579590
# exon_2 7579700 7579721
#      gene     start       end
# TP73 TP73   3569084   3652765
# TP63 TP63 189349205 189615068
# TP53 TP53   7565097   7590856
# [1] 17
# [1] "TP53"
# $ENST00000413465.2
#          start     end
# exon_7 7565097 7565332
# exon_6 7577499 7577608
# exon_5 7578177 7578289
# exon_4 7578371 7578554
# exon_3 7579312 7579590
# exon_2 7579700 7579721
# exon_1 7579839 7579912
#
# $ENST00000359597.4
# ...

# %%
#circos.initializeWithIdeogram(plotType = c("axis", "labels"))
#circos.initializeWithIdeogram(plotType = NULL)


df = data.frame(
name = c("REP", "CAP"),
start = c(1, 501),
end = c(500, 1200))
circos.genomicInitialize(df)

#read tblastn-o6-100-p.csv to retrieve the start and end of matches
data <- read.csv("C:/Users/abidd/Dropbox/algobio/rtblastn/tblastn-o6-100-p.csv", header=TRUE)
colnames(data) <- c("aav","qseqid","sseqid","pident","length","mismatch","gapopen","qstart","qend","sstart","send","evalue","bitscore")
data <- subset(data,aav == "AAV4")
head(data)
#head(data)

aav = data$aav #using $ sign is a factor list, while using data[1] create a data frame
sseqid = data$sseqid 
qstart =data$qstart
qend = data$qend

#plot Rep & Cap in different colors
circos.genomicTrackPlotRegion(ylim = c(0, 1),
bg.col = c("#FF000040", "#00FF0040"),
bg.border = NA, track.height = 0.05)

#n = max(sapply(tp_family, length))
#circos.genomicTrackPlotRegion(ylim = c(0.5, n + 0.5),
circos.genomicTrackPlotRegion(ylim = c(0.5, 17.5),
panel.fun = function(region, value, ...) {
#gn = get.cell.meta.data("sector.index")
#tr = [tp_family[[gn]]] # all transcripts for this gene
n = 10
#for(i in seq_along(tr)) {
#print(i)
# for each transcript
#current_tr_start = min(tr[[i]]$start)
#current_tr_end = max(tr[[i]]$end)
print (seq_along(sseqid))

for (i in seq_along(sseqid)){
#print (sseqid[i])

circos.lines(c(qstart[i], qend[i]),
#c(0, 0), col = "#CCCCCC")

c(n-i, n-i), col = lcc[sseqid[i]][[1]])
}
    
#}
}, bg.border = NA, track.height = 0.3)

circos.clear()
# Out:
#      aav                      qseqid sseqid pident length mismatch gapopen
# 145 AAV4 gi|9629642|ref|NP_044926.1|   chr4 34.247     73       43       2
# 146 AAV4 gi|9629642|ref|NP_044926.1|   chr4 34.043     47       30       1
# 147 AAV4 gi|9629642|ref|NP_044926.1|   chr8 25.926     81       47       3
# 148 AAV4 gi|9629642|ref|NP_044926.1|   chr8 25.000    124       76       5
# 149 AAV4 gi|9629642|ref|NP_044926.1|   chr8 30.357     56       33       2
# 150 AAV4 gi|9629642|ref|NP_044926.1|   chr8 33.766     77       45       3
#     qstart qend    sstart      send evalue bitscore
# 145    387  459 106213428 106213225    1.4     38.5
# 146     53   98 114495966 114495826   85.0     32.7
# 147    545  620   1626125   1626343    5.3     36.6
# 148    506  620   1625940   1626287   13.0     35.4
# 149    404  454 100988385 100988221   39.0     33.9
# 150     85  160 139740151 139739936   44.0     33.5
#      aav                      qseqid sseqid pident length mismatch gapopen
# ...

# %%
#to come up with 50 different colors

library(RColorBrewer)
n <- 50
qual_col_pals = brewer.pal.info[brewer.pal.info$category == 'qual',]
col_vector = unlist(mapply(brewer.pal, qual_col_pals$maxcolors, rownames(qual_col_pals)))
print (col_vector)
pie(rep(1,n), col=sample(col_vector, n)) #plot these colors into a pie
# Out:
# Warning message:
# "package 'RColorBrewer' was built under R version 3.3.2"
#  [1] "#7FC97F" "#BEAED4" "#FDC086" "#FFFF99" "#386CB0" "#F0027F" "#BF5B17"
#  [8] "#666666" "#1B9E77" "#D95F02" "#7570B3" "#E7298A" "#66A61E" "#E6AB02"
# [15] "#A6761D" "#666666" "#A6CEE3" "#1F78B4" "#B2DF8A" "#33A02C" "#FB9A99"
# [22] "#E31A1C" "#FDBF6F" "#FF7F00" "#CAB2D6" "#6A3D9A" "#FFFF99" "#B15928"
# [29] "#FBB4AE" "#B3CDE3" "#CCEBC5" "#DECBE4" "#FED9A6" "#FFFFCC" "#E5D8BD"
# [36] "#FDDAEC" "#F2F2F2" "#B3E2CD" "#FDCDAC" "#CBD5E8" "#F4CAE4" "#E6F5C9"
# [43] "#FFF2AE" "#F1E2CC" "#CCCCCC" "#E41A1C" "#377EB8" "#4DAF4A" "#984EA3"
# [50] "#FF7F00" "#FFFF33" "#A65628" "#F781BF" "#999999" "#66C2A5" "#FC8D62"
# [57] "#8DA0CB" "#E78AC3" "#A6D854" "#FFD92F" "#E5C494" "#B3B3B3" "#8DD3C7"
# [64] "#FFFFB3" "#BEBADA" "#FB8072" "#80B1D3" "#FDB462" "#B3DE69" "#FCCDE5"
# [71] "#D9D9D9" "#BC80BD" "#CCEBC5" "#FFED6F"
# plot without title
